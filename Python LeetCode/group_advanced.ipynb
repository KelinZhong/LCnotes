# %% [markdown]
# # Advanced
#
# Lower frequency in interviews. Reference depth is enough — you are unlikely to need to derive these from scratch under time pressure, but you should recognise when one applies.
#
# | Notebook | Kind | Reach for it when |
# | :--- | :--- | :--- |
# | `15_trie_and_union_find` | Cheat Sheet | Prefix queries over strings, or dynamic connectivity |
# | `16_divide_and_conquer` | Reference | The problem splits into independent halves that combine cheaply |
# | `17_bit_manipulation` | Reference | `n ≤ 20` with subsets, or "appears once / twice" |
# | `18_segment_tree_and_bit` | Reference | Range queries **with** updates — otherwise a prefix sum is simpler |
#
# Do not start here. Every notebook in Core Patterns appears more often than anything on this page.
